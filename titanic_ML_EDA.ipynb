# %%
import pandas as pd 
import numpy as np 
from pycaret.classification import ClassificationExperiment

# %% [markdown]
# ### Loading the training and testing datasets

# %%
train_df = pd.read_csv('train.csv') 
test_df = pd.read_csv('test.csv') 
print(f'Train set shape: {train_df.shape}')
print(f'Test set shape: {test_df.shape}')
# Out:
# Train set shape: (891, 12)
# Test set shape: (418, 11)

# %% [markdown]
# Previewing the training set

# %%
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Getting a list of all the titles for the training set and storing it in a list

# %%
of_title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev',
                    'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                    'Don', 'Jonkheer']         
names = list(train_df['Name'])
title_list = [] 
for i in names: 
    title_list.append(i.split()[1][:-1])
print(title_list)
# Out:
# ['Mr', 'Mrs', 'Miss', 'Mrs', 'Mr', 'Mr', 'Mr', 'Master', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mr', 'Mr', 'Miss', 'Mrs', 'Master', 'Mr', 'Planke', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Don', 'Mrs', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Planke', 'Miss', 'Mrs', 'Mrs', 'Mr', 'Miss', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Mrs', 'Master', 'Mr', 'Mrs', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Master', 'Mr', 'Miss', 'Mr', 'Master', 'Mr', 'Master', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Master', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mr', 'Miss', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Master', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mrs', 'Miss', 'Mrs', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Rev', 'Rev', 'Mrs', 'Mr', 'Billiard', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Master', 'Mr', 'Mrs', 'Mr', 'Mr', 'Master', 'Master', 'Mrs', 'Mrs', 'Mr', 'Mr', 'de', 'Master', 'Miss', 'Mr', 'Mr', 'Mr', 'Master', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Master', 'Master', 'Miss', 'Mr', 'Mrs', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mr', 'Miss', 'Master', 'Mrs', 'Miss', 'Mr', 'Mr', 'Miss', 'Miss', 'Walle', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Miss', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Miss', 'Mr', 'Mr', 'Mr', 'Dr', 'Miss', 'Mrs', 'Mr', 'Rev', 'Mr', 'Mrs', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mrs', 'Mr', 'Master', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Mrs', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mr', 'Miss', 'Miss', 'Miss', 'Mr', 'Master', 'Mrs', 'Mr', 'Mr', 'Pelsmaeker', 'Mr', 'Mr', 'Mr', 'Mulder', 'Mr', 'Mr', 'Miss', 'Miss', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mrs', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Master', 'Miss', '', 'Mr', 'Miss', 'Miss', 'Miss', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mrs', 'Dr', 'Miss', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mrs', 'Mrs', 'Miss', 'Miss', 'Mr', 'Mr', 'Planke', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Master', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Miss', 'Mrs', 'Master', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Steen', 'Miss', 'Miss', 'Miss', 'Miss', 'Mr', 'Carlo', 'Mrs', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Miss', 'Mme', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mrs', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Miss', 'Mr', 'Mrs', 'Mr', 'Mr', 'Master', 'Miss', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Mrs', 'Mr', 'Miss', 'Mr', 'Dr', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Miss', 'Mr', 'Mr', 'Master', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Miss', 'Mr', 'Impe', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mr', 'Mr', 'Mrs', 'Miss', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Mr', 'Mr', 'Miss', 'Miss', 'Mrs', 'Mr', 'Mr', 'Mrs', 'Mr', 'Mr', 'Ms', 'Mr', 'Master', 'Miss', 'Mr', 'Miss', 'Major', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mrs', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Miss', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Master', 'Mr', 'Mr', 'Mrs', 'Mr', 'Miss', 'Mrs', 'Mr', 'Mr', 'Master', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mrs', 'Mr', 'Mr', 'Miss', 'Miss', 'Miss', 'Miss', '', 'Mrs', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mr', 'Mr', 'Mrs', 'Mr', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mrs', 'Miss', 'Miss', 'Major', 'Miss', 'Mr', 'Miss', 'Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mr', 'Mrs', '', 'Mr', 'Master', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Gordon', 'Mr', 'Mrs', 'Messemaeker', 'Mr', 'Mr', 'Mr', 'Mr', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mr', 'Mr', 'Mr', 'Mrs', 'Mr', 'Miss', 'Mr', 'Mr', 'Miss', 'Mrs', 'Mrs', 'Mr', 'Miss', 'Mrs', ...

# %% [markdown]
# Replacing the individual names with the titles

# %%
train_df['Name'] = title_list
train_df.rename(columns = {'Name':'Title'}, inplace = True,errors='ignore')
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# Checking the number of unique titles in the dataframe

# %%
print(f"Number of unique titles: {train_df['Title'].nunique()}")
# Out:
# Number of unique titles: 31

# %%
train_df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Planke', 'Don', 'Rev', 'Billiard',
#        'de', 'Walle', 'Dr', 'Pelsmaeker', 'Mulder', '', 'Steen', 'Carlo',
#        'Mme', 'Impe', 'Ms', 'Major', 'Gordon', 'Messemaeker', 'Mlle',
#        'Col', 'Capt', 'Velde', 'th', 'Shawah', 'Jonkheer', 'Melkebeke',
#        'Cruyssen'], dtype=object)

# %% [markdown]
# Filtering the training dataframe to only contain titles from the list

# %%
filtered_train_df = train_df[train_df['Title'].isin(of_title_list)]
print(f'Filtered train set shape: {filtered_train_df.shape}')
filtered_train_df['Title'].unique()
# Out:
# Filtered train set shape: (866, 12)
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Mlle', 'Col', 'Capt', 'Jonkheer'], dtype=object)

# %%
filtered_train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# Reducing the number of titles down to four: Mr, Mrs, Miss, Master

# %%
def replace_titles(x):
    title=x['Title']
    if title in ['Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
        return 'Mr'
    if title in ['Countess', 'Mme']:
        return 'Mrs'
    if title in ['Mlle', 'Ms']:
        return 'Miss'
    if title =='Dr':
        if x['Sex']=='Male':
            return 'Mr'
        else:
            return 'Mrs'
    else:
        return title
#Applying the function to the dataframe 
filtered_train_df['Title'] = filtered_train_df.apply(replace_titles,axis=1)
filtered_train_df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master'], dtype=object)

# %%
filtered_train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
print(f"Number of unique titles: {filtered_train_df['Title'].nunique()}")
# Out:
# Number of unique titles: 4

# %% [markdown]
# For the cabins we have numbers, let's replace the individual unique cabin numbers to categories

# %%
filtered_train_df['Cabin'] = filtered_train_df['Cabin'].fillna('U')

# %%
cabin_list = list(filtered_train_df['Cabin'])
new_list = [] 
for i in cabin_list: 
    new_list.append(list(i)[0])
filtered_train_df['Cabin'] = new_list

# %%
filtered_train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500     U        S
# 1          PC 17599  71.2833     C        C
# 2  STON/O2. 3101282   7.9250     U        S
# 3            113803  53.1000     C        S
# 4            373450   8.0500     U        S

# %% [markdown]
# Getting the family size for every passenger in the dataframe

# %%
filtered_train_df['Family_Size']=filtered_train_df['SibSp']+filtered_train_df['Parch']
filtered_train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Family_Size
# 0         A/5 21171   7.2500     U        S            1
# 1          PC 17599  71.2833     C        C            1
# 2  STON/O2. 3101282   7.9250     U        S            0
# 3            113803  53.1000     C        S            1
# 4            373450   8.0500     U        S            0

# %%
filtered_train_df['Age*Class']=filtered_train_df['Age']*filtered_train_df['Pclass']
filtered_train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Family_Size  Age*Class
# 0         A/5 21171   7.2500     U        S            1       66.0
# 1          PC 17599  71.2833     C        C            1       38.0
# 2  STON/O2. 3101282   7.9250     U        S            0       78.0
# 3            113803  53.1000     C        S            1       35.0
# 4            373450   8.0500     U        S            0      105.0

# %%
filtered_train_df['Fare_Per_Person']=filtered_train_df['Fare']/(filtered_train_df['Family_Size']+1)
filtered_train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass Title     Sex   Age  SibSp  Parch  \
# 0            1         0       3    Mr    male  22.0      1      0
# 1            2         1       1   Mrs  female  38.0      1      0
# 2            3         1       3  Miss  female  26.0      0      0
# 3            4         1       1   Mrs  female  35.0      1      0
# 4            5         0       3    Mr    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Family_Size  Age*Class  \
# 0         A/5 21171   7.2500     U        S            1       66.0
# 1          PC 17599  71.2833     C        C            1       38.0
# 2  STON/O2. 3101282   7.9250     U        S            0       78.0
# 3            113803  53.1000     C        S            1       35.0
# 4            373450   8.0500     U        S            0      105.0
#
#    Fare_Per_Person
# 0          3.62500
# 1         35.64165
# 2          7.92500
# 3         26.55000
# 4          8.05000

# %% [markdown]
# Removing the unneeded columns, PassengerID and Ticket

# %%
filtered_train_df.drop(columns=['PassengerId','Ticket'], inplace=True,errors='ignore')
filtered_train_df.head(5)
# Out:
#    Survived  Pclass Title     Sex   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0         0       3    Mr    male  22.0      1      0   7.2500     U        S
# 1         1       1   Mrs  female  38.0      1      0  71.2833     C        C
# 2         1       3  Miss  female  26.0      0      0   7.9250     U        S
# 3         1       1   Mrs  female  35.0      1      0  53.1000     C        S
# 4         0       3    Mr    male  35.0      0      0   8.0500     U        S
#
#    Family_Size  Age*Class  Fare_Per_Person
# 0            1       66.0          3.62500
# 1            1       38.0         35.64165
# 2            0       78.0          7.92500
# 3            1       35.0         26.55000
# 4            0      105.0          8.05000

# %% [markdown]
# Machine Learning!

# %%
s = ClassificationExperiment() 
s.setup(filtered_train_df,target='Survived',session_id=123)
# Out:
# <style type="text/css">
# #T_10054_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_10054">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10054_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_10054_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10054_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10054_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_10054_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_10054_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_10054_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_10054_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_10054_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_10054_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_10054_row3_col1" class="data row3 col1" >(866, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_10054_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_10054_row4_col1" class="data row4 col1" >(866, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_10054_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_10054_row5_col1" class="data row5 col1" >(606, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_10054_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_10054_row6_col1" class="data row6 col1" >(260, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_10054_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_10054_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_10054_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_10054_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_10054_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_10054_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_10054_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_10054_row10_col1" class="data row10 col1" >20.4%</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_10054_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_10054_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_10054_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_10054_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_10054_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_10054_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_10054_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_10054_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_10054_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_10054_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_10054_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_10054_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_10054_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_10054_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_10054_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_10054_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_10054_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_10054_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_10054_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_10054_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_10054_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_10054_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_10054_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_10054_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_10054_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_10054_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_10054_row23_col1" class="data row23 col1" >80ad</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_0bdc0 th {
#   text-align: left;
# }
# #T_0bdc0_row0_col0, #T_0bdc0_row0_col3, #T_0bdc0_row1_col0, #T_0bdc0_row1_col1, #T_0bdc0_row1_col2, #T_0bdc0_row1_col3, #T_0bdc0_row1_col4, #T_0bdc0_row1_col5, #T_0bdc0_row1_col6, #T_0bdc0_row1_col7, #T_0bdc0_row2_col0, #T_0bdc0_row2_col1, #T_0bdc0_row2_col2, #T_0bdc0_row2_col3, #T_0bdc0_row2_col4, #T_0bdc0_row2_col5, #T_0bdc0_row2_col6, #T_0bdc0_row2_col7, #T_0bdc0_row3_col0, #T_0bdc0_row3_col1, #T_0bdc0_row3_col2, #T_0bdc0_row3_col3, #T_0bdc0_row3_col4, #T_0bdc0_row3_col5, #T_0bdc0_row3_col6, #T_0bdc0_row3_col7, #T_0bdc0_row4_col0, #T_0bdc0_row4_col1, #T_0bdc0_row4_col2, #T_0bdc0_row4_col3, #T_0bdc0_row4_col4, #T_0bdc0_row4_col5, #T_0bdc0_row4_col6, #T_0bdc0_row4_col7, #T_0bdc0_row5_col0, #T_0bdc0_row5_col1, #T_0bdc0_row5_col2, #T_0bdc0_row5_col3, #T_0bdc0_row5_col4, #T_0bdc0_row5_col5, #T_0bdc0_row5_col6, #T_0bdc0_row5_col7, #T_0bdc0_row6_col0, #T_0bdc0_row6_col1, #T_0bdc0_row6_col2, #T_0bdc0_row6_col3, #T_0bdc0_row6_col4, #T_0bdc0_row6_col5, #T_0bdc0_row6_col6, #T_0bdc0_row6_col7, #T_0bdc0_row7_col0, #T_0bdc0_row7_col1, #T_0bdc0_row7_col2, #T_0bdc0_row7_col4, #T_0bdc0_row7_col5, #T_0bdc0_row7_col6, #T_0bdc0_row7_col7, #T_0bdc0_row8_col0, #T_0bdc0_row8_col1, #T_0bdc0_row8_col2, #T_0bdc0_row8_col3, #T_0bdc0_row8_col4, #T_0bdc0_row8_col5, #T_0bdc0_row8_col6, #T_0bdc0_row8_col7, #T_0bdc0_row9_col0, #T_0bdc0_row9_col1, #T_0bdc0_row9_col2, #T_0bdc0_row9_col3, #T_0bdc0_row9_col4, #T_0bdc0_row9_col5, #T_0bdc0_row9_col6, #T_0bdc0_row9_col7, #T_0bdc0_row10_col0, #T_0bdc0_row10_col1, #T_0bdc0_row10_col2, #T_0bdc0_row10_col3, #T_0bdc0_row10_col4, #T_0bdc0_row10_col5, #T_0bdc0_row10_col6, #T_0bdc0_row10_col7, #T_0bdc0_row11_col0, #T_0bdc0_row11_col1, #T_0bdc0_row11_col2, #T_0bdc0_row11_col3, #T_0bdc0_row11_col4, #T_0bdc0_row11_col5, #T_0bdc0_row11_col6, #T_0bdc0_row11_col7, #T_0bdc0_row12_col0, #T_0bdc0_row12_col1, #T_0bdc0_row12_col2, #T_0bdc0_row12_col3, #T_0bdc0_row12_col4, #T_0bdc0_row12_col5, #T_0bdc0_row12_col6, #T_0bdc0_row12_col7, #T_0bdc0_row13_col0, #T_0bdc0_row13_col1, #T_0bdc0_row13_col2, #T_0bdc0_row13_col3, #T_0bdc0_row13_col4, #T_0bdc0_row13_col5, #T_0bdc0_row13_col6, #T_0bdc0_row13_col7, #T_0bdc0_row14_col0, #T_0bdc0_row14_col1, #T_0bdc0_row14_col2, #T_0bdc0_row14_col3, #T_0bdc0_row14_col4, #T_0bdc0_row14_col5, #T_0bdc0_row14_col6, #T_0bdc0_row14_col7 {
#   text-align: left;
# }
# #T_0bdc0_row0_col1, #T_0bdc0_row0_col2, #T_0bdc0_row0_col4, #T_0bdc0_row0_col5, #T_0bdc0_row0_col6, #T_0bdc0_row0_col7, #T_0bdc0_row7_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0bdc0_row0_col8, #T_0bdc0_row1_col8, #T_0bdc0_row2_col8, #T_0bdc0_row3_col8, #T_0bdc0_row4_col8, #T_0bdc0_row5_col8, #T_0bdc0_row6_col8, #T_0bdc0_row7_col8, #T_0bdc0_row8_col8, #T_0bdc0_row9_col8, #T_0bdc0_row10_col8, #T_0bdc0_row11_col8, #T_0bdc0_row13_col8, #T_0bdc0_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0bdc0_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0bdc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bdc0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0bdc0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_0bdc0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_0bdc0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_0bdc0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_0bdc0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_0bdc0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_0bdc0_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_0bdc0_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bdc0_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_0bdc0_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_0bdc0_row0_col1" class="data row0 col1" >0.8236</td>
#       <td id="T_0bdc0_row0_col2" class="data row0 col2" >0.8656</td>
#       <td id="T_0bdc0_row0_col3" class="data row0 col3" >0.7614</td>
#       <td id="T_0bdc0_row0_col4" class="data row0 col4" >0.7813</td>
#       <td id="T_0bdc0_row0_col5" class="data row0 col5" >0.7695</td>
#       <td id="T_0bdc0_row0_col6" class="data row0 col6" >0.6268</td>
#       <td id="T_0bdc0_row0_col7" class="data row0 col7" >0.6286</td>
#       <td id="T_0bdc0_row0_col8" class="data row0 col8" >0.1750</td>
#     </tr>
#     <tr>
#       <th id="T_0bdc0_level0_row1" class="row_heading level0 row1" >lda</th>
#       <td id="T_0bdc0_row1_col0" class="data row1 col0" >Linear Discriminant Analysis</td>
#       <td id="T_0bdc0_row1_col1" class="data row1 col1" >0.8203</td>
#       <td id="T_0bdc0_row1_col2" class="data row1 col2" >0.8611</td>
#       <td id="T_0bdc0_row1_col3" class="data row1 col3" >0.7658</td>
#       <td id="T_0bdc0_row1_col4" class="data row1 col4" >0.7745</td>
#       <td id="T_0bdc0_row1_col5" class="data row1 col5" >0.7679</td>
#       <td id="T_0bdc0_row1_col6" class="data row1 col6" >0.6215</td>
#       <td id="T_0bdc0_row1_col7" class="data row1 col7" >0.6238</td>
#       <td id="T_0bdc0_row1_col8" class="data row1 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_0bdc0_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_0bdc0_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_0bdc0_row2_col1" class="data row2 col1" >0.8187</td>
#       <td id="T_0bdc0_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_0bdc0_row2_col3" class="data row2 col3" >0.7572</td>
#       <td id="T_0bdc0_row2_col4" class="data row2 col4" >0.7752</td>
#       <td id="T_0bdc0_row2_col5" class="data row2 col5" >0.7644</td>
#       <td id="T_0bdc0_row2_col6" class="data row2 col6" >0.6171</td>
#       <td id="T_0bdc0_row2_col7" class="data row2 col7" >0.6191</td>
#       <td id="T_0bdc0_row2_col8" class="data row2 col8" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_0bdc0_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_0bdc0_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_0bdc0_row3_col1" class="data row3 col1" >0.8136</td>
#       <td id="T_0bdc0_row3_col2" class="data row3 col2" >0.8504</td>
#       <td id="T_0bdc0_row3_col3" class="data row3 col3" >0.7697</td>
#       <td id="T_0bdc0_row3_col4" class="data row3 col4" >0.7602</td>
#       <td id="T_0bdc0_row3_col5" class="data row3 col5" >0.7615</td>
#       <td id="T_0bdc0_row3_col6" class="data row3 col6" >0.6089</td>
#       <td id="T_0bdc0_row3_col7" class="data row3 col7" >0.6127</td>
#       <td id="T_0bdc0_row3_col8" class="data row3 col8" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_0bdc0_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_0bdc0_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_0bdc0_row4_col1" class="data row4 col1" >0.8120</td>
#       <td id="T_0bdc0_row4_col2" class="data row4 col2" >0.8644</td>
#       <td id="T_0bdc0_row4_col3" class="data row4 col3" >0.7263</td>
#       <td id="T_0bdc0_row4_col4" class="data row4 col4" >0.7798</td>
#       <td id="T_0bdc0_row4_col5" class="data row4 col5" >0.7497</td>
#       <td id="T_0bdc0_row4_col6" class="data row4 col6" >0.5995</td>
#       <td id="T_0bdc0_row4_col7" class="data row4 col7" >0.6028</td>
#       <td id="T_0bdc0_row4_col8" class="data row4 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_0bdc0_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_0bdc0_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0bdc0_row5_col1" class="data row5 col1" >0.7937</td>
#       <td id="T_0bdc0_row5_col2" class="data row5 col2" >0.8447</td>
#       <td id="T_0bdc0_row5_col3" class="data row5 col3" >0.7047</td>
#       <td id="T_0bdc0_row5_col4" class="data row5 col4" >0.7549</td>
#       <td id="T_0bdc0_

# %%
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
pred_holdout = s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_089ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_089ef_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_089ef_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_089ef_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_089ef_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_089ef_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_089ef_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_089ef_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_089ef_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_089ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_089ef_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_089ef_row0_col1" class="data row0 col1" >0.8308</td>
#       <td id="T_089ef_row0_col2" class="data row0 col2" >0.8805</td>
#       <td id="T_089ef_row0_col3" class="data row0 col3" >0.8000</td>
#       <td id="T_089ef_row0_col4" class="data row0 col4" >0.7692</td>
#       <td id="T_089ef_row0_col5" class="data row0 col5" >0.7843</td>
#       <td id="T_089ef_row0_col6" class="data row0 col6" >0.6452</td>
#       <td id="T_089ef_row0_col7" class="data row0 col7" >0.6455</td>
#     </tr>
#   </tbody>
# </table>

# %%
s.save_model(best,'best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/var/folders/_f/1mj9zrs94csb737st13h9w3c0000gn/T/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Pclass', 'Age', 'SibSp', 'Parch',
#                                               'Fare', 'Family_Size', 'Age*Class',
#                                               'Fare_Per_Person'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing...
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=123,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'best_pipeline.pkl')
